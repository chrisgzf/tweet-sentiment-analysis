# %% [markdown]
# # 2. Dataset Creation - Mining Mood Tweets from Twitter API
#
# Now that our proof-of-concept that the sentiment analysis training method works, We will now collate our mood tweets dataset. I will refer to the sad/happy tweets as "mood tweets" from here on.

# %% [markdown]
# We will be using the Twitter Premium Search API (Sandbox version). Do note that it is free for the Sandbox version (limited functionality, but just enough for us to gather our dataset). The Twitter Premium Search API is a RESTful API that requires us to create:
#
# 1. A Twitter App - https://developer.twitter.com/en/apps
# 2. A Dev Environment for the App - https://developer.twitter.com/en/account/environments
#
# API Reference: https://developer.twitter.com/en/docs/tweets/search/api-reference/premium-search
#
# **Why the Twitter Premium Search API:**
# - Gives us ability to use operators to refine our search, to get cleaner data (for example, english only suicidal tweets can be expressed as "suicidal OR suicide OR "kill myself" lang:en"
# - Free version gives us 250 queries in a month, with each query giving us 100 tweets. 25000 tweets should form a sufficiently large dataset
# - The API reference is really quite good
# - I tried the free "Standard Search API", doesn't return full tweets.
#
# You will have to register for a developer account to get the API keys in order to follow along this notebook. Otherwise, you can just follow my output here.

# %%
import requests
import my_api_keys as api_keys

# to get your bearer token, go to https://developer.twitter.com/en/docs/basics/authentication/guides/bearer-tokens
# edit my_api_keys_SAMPLE.py to my_api_keys.py and put your token it in

bearer_access_token = api_keys.bearer_access_token

# %% [markdown]
# Here, we will set up the POST request to query the premium search API. Our query must have these few premium operators in it:
# - `lang:en` - to search only English tweets
# - `-has:links` - the hyphen is a negation operator (NOT), we want to only search for tweets WITHOUT links, so that we can filter out advertisements
# - `-has:media` - tweets WITHOUT media, for me I thought it was more likely to get real "mood tweets" if we filter out tweets with media, to remove those "meme" or "gif" tweets
# - there was also one more flag I wanted to add but unfortunately cannot, because the free Sandbox version of the API does not allow for this flag, `-is:retweet`, which filters out retweets. Retweets should be filtered because they are very likely to contain "emo quotes twitter accounts" or advertisements

# %%
# endpoint URI is https://api.twitter.com/1.1/tweets/search/30day/<YOUR DEV ENV NAME>.json
endpoint = "https://api.twitter.com/1.1/tweets/search/30day/dev.json"

headers = {
    "Authorization" : "Bearer " + bearer_access_token,
    "Content-Type": "application/json",
}

queries = {
    "suicidal" : 'suicidal OR suicide OR "kill myself"',
    "depressed" : "depressed OR depression",
    "sad" : "sad -depressed -suicidal -suicide",
    "happy" : "happy OR great -sadness -depression -disappointment",
    "cheerful" : "cheerful OR awesome OR glad OR pleased",
    "overjoyed" : "overjoyed OR elated OR ecstatic OR thrilled",
}

# %%
# do your math and calculate how many sets of 100 tweets per class you want
# you have a limit of 250 queries in a month for the sandbox version of the API
# DON'T SCREW THIS UP OR YOU WILL WASTE QUERIES
NO_OF_QUERIES_PER_CLASS = 40

# %%
from datetime import datetime
import os
import time
import json

# Directory creation for dataset
DATASET_ROOT_DIR = ""
if not os.path.exists("./datasets/mood_tweets/"):
    os.mkdir("./datasets/mood_tweets/")
if not os.path.exists("./datasets/mood_tweets/" + datetime.now().strftime("%Y%m%d-%H%M")):
    DATASET_ROOT_DIR = "./datasets/mood_tweets/" + datetime.now().strftime("%Y%m%d-%H%M")
    os.mkdir(DATASET_ROOT_DIR)
else:
    print("You sure? The directory already exists!")
    raise KeyboardInterrupt

# Actual API Querying Part
query_params = {
    'query' : '', # blank string because we populate it later in the loop
    'maxResults' : '100',
}

for class_name, current_query in queries.items():
    print(class_name)
    
    # set the right query term
    query_params["query"] = current_query + ' -has:links -has:media lang:en'
    
    # remove "next" parameter from previous term's pagination
    if "next" in query_params:
        query_params.pop("next")
        
    # load initial query
    data = json.dumps(query_params)
    
    for n in range(0, NO_OF_QUERIES_PER_CLASS):

        # query API
        response = requests.post(endpoint, data=data, headers=headers)
        response_json = json.loads(response.text)
        
        # write response to file
        filename = "{}/{}-{}.json".format(DATASET_ROOT_DIR, class_name, format(n, '03'))
        with open(filename, "w") as file:
            json.dump(response_json, file, ensure_ascii=False, indent=4)
        print(filename)
        
        # pause to query API slower
        time.sleep(1)
        
        # handle pagination for next call
        if "next" in response_json:
            query_params["next"] = response_json["next"]
            data = json.dumps(query_params)
        else:
            # we maxed out the number of pages for this available term, this is the last "page" of results
            print("Ended prematurely at {} because no further pages are available".format(filename))
            break

print("DONE")
# Out:
# happy
# ./datasets/mood_tweets/20190405-0528/happy-000.json
# ./datasets/mood_tweets/20190405-0528/happy-001.json
# ./datasets/mood_tweets/20190405-0528/happy-002.json
# ./datasets/mood_tweets/20190405-0528/happy-003.json
# ./datasets/mood_tweets/20190405-0528/happy-004.json
# ./datasets/mood_tweets/20190405-0528/happy-005.json
# ./datasets/mood_tweets/20190405-0528/happy-006.json
# ./datasets/mood_tweets/20190405-0528/happy-007.json
# ./datasets/mood_tweets/20190405-0528/happy-008.json
# ./datasets/mood_tweets/20190405-0528/happy-009.json
# ./datasets/mood_tweets/20190405-0528/happy-010.json
# ./datasets/mood_tweets/20190405-0528/happy-011.json
# ./datasets/mood_tweets/20190405-0528/happy-012.json
# ./datasets/mood_tweets/20190405-0528/happy-013.json
# ./datasets/mood_tweets/20190405-0528/happy-014.json
# ./datasets/mood_tweets/20190405-0528/happy-015.json
# ./datasets/mood_tweets/20190405-0528/happy-016.json
# ./datasets/mood_tweets/20190405-0528/happy-017.json
# ./datasets/mood_tweets/20190405-0528/happy-018.json
# ./datasets/mood_tweets/20190405-0528/happy-019.json
# ./datasets/mood_tweets/20190405-0528/happy-020.json
# ./datasets/mood_tweets/20190405-0528/happy-021.json
# ./datasets/mood_tweets/20190405-0528/happy-022.json
# ./datasets/mood_tweets/20190405-0528/happy-023.json
# ./datasets/mood_tweets/20190405-0528/happy-024.json
# ./datasets/mood_tweets/20190405-0528/happy-025.json
# ./datasets/mood_tweets/20190405-0528/happy-026.json
# ./datasets/mood_tweets/20190405-0528/happy-027.json
# ./datasets/mood_tweets/20190405-0528/happy-028.json
# ./datasets/mood_tweets/20190405-0528/happy-029.json
# ./datasets/mood_tweets/20190405-0528/happy-030.json
# ./datasets/mood_tweets/20190405-0528/happy-031.json
# ./datasets/mood_tweets/20190405-0528/happy-032.json
# ./datasets/mood_tweets/20190405-0528/cheerful-056.json
# ./datasets/mood_tweets/20190405-0528/cheerful-057.json
# ./datasets/mood_tweets/20190405-0528/cheerful-058.json
# ./datasets/mood_tweets/20190405-0528/cheerful-059.json
# ./datasets/mood_tweets/20190405-0528/cheerful-060.json
# ./datasets/mood_tweets/20190405-0528/cheerful-061.json
# ./datasets/mood_tweets/20190405-0528/cheerful-062.json
# ./datasets/mood_tweets/20190405-0528/cheerful-063.json
# ./datasets/mood_tweets/20190405-0528/cheerful-064.json
# ./datasets/mood_tweets/20190405-0528/cheerful-065.json
# ./datasets/mood_tweets/20190405-0528/cheerful-066.json
# ./datasets/mood_tweets/20190405-0528/cheerful-067.json
# ./datasets/mood_tweets/20190405-0528/cheerful-068.json
# ./datasets/mood_tweets/20190405-0528/cheerful-069.json
# ./datasets/mood_tweets/20190405-0528/cheerful-070.json
# ./datasets/mood_tweets/20190405-0528/cheerful-071.json
# ./datasets/mood_tweets/20190405-0528/cheerful-072.json
# ./datasets/mood_tweets/20190405-0528/cheerful-073.json
# ./datasets/mood_tweets/20190405-0528/cheerful-074.json
# ./datasets/mood_tweets/20190405-0528/cheerful-075.json
# ./datasets/mood_tweets/20190405-0528/cheerful-076.json
# ./datasets/mood_tweets/20190405-0528/cheerful-077.json
# ./datasets/mood_tweets/20190405-0528/cheerful-078.json
# ./datasets/mood_tweets/20190405-0528/cheerful-079.json
# overjoyed
# ./datasets/mood_tweets/20190405-0528/overjoyed-000.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-001.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-002.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-003.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-004.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-005.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-006.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-007.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-008.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-009.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-010.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-011.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-012.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-013.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-014.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-015.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-016.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-017.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-018.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-019.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-020.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-021.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-022.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-023.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-024.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-025.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-026.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-027.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-028.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-029.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-030.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-031.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-032.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-033.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-034.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-035.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-036.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-037.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-038.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-039.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-040.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-041.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-042.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-043.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-044.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-045.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-046.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-047.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-048.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-049.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-050.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-051.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-052.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-053.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-054.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-055.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-056.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-057.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-058.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-059.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-060.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-061.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-062.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-063.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-064.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-065.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-066.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-067.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-068.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-069.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-070.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-071.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-072.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-073.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-074.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-075.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-076.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-077.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-078.json
# ./datasets/mood_tweets/20190405-0528/overjoyed-079.json
# DONE

# %% [markdown]
# ## Cleaning up the dataset
#
# Before mass processing all the data, we are going to process a sample of one of the files to see if they are complete / can be extracted without issues first.

# %%
sample_file = './datasets/mood_tweets/20190405-0528/overjoyed-079.json'

with open(sample_file, "r") as file:
    result = json.loads(file.read())
    filename = os.path.basename(file.name)
    classname = filename.split("-")[0]
classname
# Out:
# 'overjoyed'

# %%
print(len(result["results"]), "tweets found")
# Out:
# 100 tweets found

# %%
for x in result["results"]:
    if "retweeted_status" in x:
        if "extended_tweet" in x["retweeted_status"]:
            print("\nRETWEET - LONG")
            print(x["retweeted_status"]["extended_tweet"]["full_text"])
        else:
            print("\nRETWEET - SHORT")
            print(x["retweeted_status"]["text"])
    elif "extended_tweet" in x:
        print("\nNORMAL TWEET - LONG")
        print(x["extended_tweet"]["full_text"])
    else:
        print("\nNORMAL TWEET - SHORT")
        print(x["text"])
# Out:
# RETWEET - SHORT
# Nerves broken, almost a heart attack, but overjoyed ❤️ #FCBFCH #DFBPokal https://t.co/sMWG0h5GaV
#
# NORMAL TWEET - SHORT
# @ecstatic_shocks koreabooism at it’s finest🤡
#
# RETWEET - LONG
# Special to hit helicopter shot with @msdhoni watching: Hardik
#
# "Hoped MS would congratulate me after that shot 😜"
# An overjoyed @hardikpandya7 talks about emulating inspiration MSD's pet stroke against CSK. Interview by @Moulinparikh #MIvCSK @mipaltan
#
# 📹 https://t.co/jLLWXuZRYe https://t.co/aci6s6cPBF
#
# RETWEET - LONG
# Thrilled to hear @UnitedWaySummit is expanding their diversity, equity, &amp; inclusion work! @SummitArtsNow partnered w/ UWSC in March on a social service+arts, culture, and environment collaboration. Looking forward to the next phase! Thank you Andre Campbell and Adrienne Bradley!
#
# RETWEET - LONG
# Thrilled to join @PKMackie &amp; @cardiffbusiness for breakfast briefing on homelessness. Thank you for such a warm &amp;  positive response - @LlamauUK &amp;  EYHC’s message is that each and everyone of us in Wales needs to commit to playing our part in preventing and ending homelessness 💪
#
# RETWEET - SHORT
# WATCH: PBB Otso Batch 2 Housemates are all elated meeting each other again. #StarHuntGrandMediacon https://t.co/Vl85KVkqAc
#
# RETWEET - LONG
# Penggunaan "less very" pada kalimat
#
# very sad = sorrowfull
# very crowded = bustling
# very confused = perplexed
# very happy = ecstatic
# very difficult = arduous
# very quick = rapid
# very bad = awful
# very smart = intelligent
# very beautiful = kamu
#
# RETWEET - SHORT
# beyond thrilled to announce that i am going to bed!!!
#
# NORMAL TWEET - LONG
# Nervously waiting to find out whether I've got a place at @ActUpNorth after my audition on Monday evening. Lots of experienced actors at the session so not fancying my chances but would be overjoyed if I got in!
#
# RETWEET - LONG
# I am thrilled to announce that I am the recipient of the 2019 Thrilled to Announce Award.  See you all at the Conference Awards Dinner where I will be thrilled to receive it. Thrilled! 🙏🏻
#
# NORMAL TWEET - LONG
# 【SM fetish BAR gaLa ecstatic】
# 本日4月4日も
# gaLa ecstaticは20時より、
# RituaLは22時より営業致します🍾
#
# 皆様のご来店を心よりお待ちしております💁‍♀️
#
# #gaLa #RituaL #神戸BAR #SMbar #カラオケBAR https://t.co/wlOhaq7mab
#
# NORMAL TWEET - LONG
# I was elated seeing these beautiful young girls, doing this nation proud last yr, defeating U.S, China and other countries in the final winning the Gold Medal Award. I doubt if they were honoured and given warm reception by the president till today for this great exploit. https://t.co/0U0LjLXrux
#
# RETWEET - LONG
# God is not thrilled about self-pity either. Numbers 11:10 KJV
# [10] Then MOSES HEARD THE PEOPLE WEEP THROUGHOUT THEIR FAMILIES, every man in the door of his tent: and THE ANGER OF THE LORD WAS KINDLED GREATLY; Moses also was displeased.
#
# RETWEET - LONG
# *STOLEN FROM REDDIT*
#
# This shit is so beautiful man, gave me chills. I am ECSTATIC for the playoffs to begin &amp; to watch Avengers Endgame. LETS GO RAPTORS!!!!!!!!!!! https://t.co/sE4lZfUW8B
# Aine sounds positively thrilled that you were so happy about that....
# It's like she didn't love Maurice at all, and she was just admiring the sunny weather.
#
# NORMAL TWEET - LONG
# Aine sounds positively thrilled that you were so happy about that....
# It's like she didn't love Maurice at all, and she was just admiring the sunny weather.
#
# NORMAL TWEET - SHORT
# @laaizard yes pls! people will be thrilled!
#
# RETWEET - SHORT
# Grade 9 life is of the most memorable and ecstatic moment of my life💖
#
# NORMAL TWEET - LONG
# Thrilled to join @PKMackie &amp; @cardiffbusiness for breakfast briefing on homelessness. Thank you for such a warm &amp;  positive response - @LlamauUK &amp;  EYHC’s message is that each and everyone of us in Wales needs to commit to playing our part in preventing and ending homelessness 💪
#
# RETWEET - LONG
# Special to hit helicopter shot with @msdhoni watching: Hardik
#
# "Hoped MS would congratulate me after that shot 😜"
# An overjoyed @hardikpandya7 talks about emulating inspiration MSD's pet stroke against CSK. Interview by @Moulinparikh #MIvCSK @mipaltan
#
# 📹 https://t.co/jLLWXuZRYe https://t.co/aci6s6cPBF
#
# NORMAL TWEET - SHORT
# A #chowkidar started following me; should I be concerned or thrilled?
#
# RETWEET - SHORT
# We're absolutely ecstatic to partner with @Duracell as we bring its business into the future of power⚡️ https://t.co/jVxpmj6Fcx
#
# NORMAL TWEET - SHORT
# @mpershan @carloliwitter @jasmineyma 😭 I’m thrilled to be spending Saturday w the kids, but I am sad to miss this. Let me know how it is!
#
# NORMAL TWEET - SHORT
# Btch i'm thrilled
#
# NORMAL TWEET - SHORT
# @AKADonaldTrump He’s obviously not thrilled about either prospect.
#
# NORMAL TWEET - SHORT
# @FranklinDuque7 oh for sure the one for switch i am so thrilled to play
#
# NORMAL TWEET - SHORT
# @DeMistyB Earned and deserved. So thrilled for you, my friend.❤️
#
# NORMAL TWEET - LONG
# @andreasavgousti @steve45220 That's why I prefer H20. Laurie vs Michael.
#
# And yes, I adore Halloween II so wasn't ecstatic that they jettisoned it from the storyline.
#
# No need.
#
# NORMAL TWEET - SHORT
# @KalynNicholson @arthurtparra I’m thrilled! 😍🤩 Please tell us where and how you guys met!!!
#
# RETWEET - LONG
# Thrilled to announce our paper investigating neural network connectivity changes in people with #aphasia following use of our #iReadMore reading therapy app has been accepted by @SfNJournals #Jneurosci 🎉 S Kerry, W Penny @ZWoodhead @oscaraguilarmej @alexander_leff @CrinionJenny
#
# RETWEET - LONG
# To H'wood celebs whining about @BrianKempGA who are parents: when U first heard UR child’s heartbeat through ultrasound, did U yawn, “It’s a meaningless sound from a lump of tissue &amp; OK to shred” or did U feel thrilled and say, “It’s our baby’s heartbeat!”?
#
# RETWEET - SHORT
# Cell phone video captures the moment the ecstatic Ben Stiller fan realizes she's on the same train as the actor https://t.co/erFQ4woX3z
#
# RETWEET - LONG
# Special to hit helicopter shot with @msdhoni watching: Hardik
#
# "Hoped MS would congratulate me after that shot 😜"
# An overjoyed @hardikpandya7 talks about emulating inspiration MSD's pet stroke against CSK. Interview by @Moulinparikh #MIvCSK @mipaltan
#
# "Hoped MS would congratulate me after that shot 😜"
# An overjoyed @hardikpandya7 talks about emulating inspiration MSD's pet stroke against CSK. Interview by @Moulinparikh #MIvCSK @mipaltan
#
# 📹 https://t.co/jLLWXuZRYe https://t.co/aci6s6cPBF
#
# RETWEET - LONG
# Special to hit helicopter shot with @msdhoni watching: Hardik
#
# "Hoped MS would congratulate me after that shot 😜"
# An overjoyed @hardikpandya7 talks about emulating inspiration MSD's pet stroke against CSK. Interview by @Moulinparikh #MIvCSK @mipaltan
#
# 📹 https://t.co/jLLWXuZRYe https://t.co/aci6s6cPBF
#
# NORMAL TWEET - SHORT
# @stevephipps83 @tim_spiers_Star He looks thrilled
#
# NORMAL TWEET - LONG
# The always in-vogue and recognized design fair - #MilanDesign Week starts next week. And we're elated to announce our presence at their  5VIE ART + DESIGN location from 9th - 14th April 2019.
# #LivingWithElan looks forward to seeing you there!
#
# #MilanDesignWeek #Milan #ElanStyle https://t.co/UFwzGkooCl
#
# RETWEET - LONG
# Thank you! I’m overjoyed by the support &amp; energy we have received!  $231,000 in 7 weeks- an average of $75 per donor.   Folks are ready to #SendLindseyHome
#
# We will make a BIG announcement soon but we need your help to keep the momentum going!  #JoinJaime https://t.co/M3xcZGn8RZ https://t.co/hLDc8RBQjG
#
# RETWEET - LONG
# Thank you, Trina, your trust means a lot for us. We were elated to see you happy and healthy. Enjoy the goodie bag with some extra love for you. #happyclient #bestreview #attorneyreview #goodiebag #clientselfie
#
# NORMAL TWEET - LONG
# @lzjwilliams @CarolAnnCAC @TomKeene647 @stuartbman @ukpenguin We'd be thrilled to see the pins being used in NZ!  If you DM me your address, we'll send some over ✈️
#
# NORMAL TWEET - LONG
# @lzjwilliams @CarolAnnCAC @TomKeene647 @stuartbman @ukpenguin We'd be thrilled to see the pins being used in NZ!  If you DM me your address, we'll send some over ✈️
#
# NORMAL TWEET - LONG
# We're thrilled to be featured on the Irish Tech News . In an exiting interview with our CEO, Eddie Postma, about his journey as an entrepreneur and the work we do here at Parksen. @SimonCocking #iot #blockchain #PARQtoken #GoGreen #SmartCity #SmartParking

# %% [markdown]
# Awesome! Now we need to think of how to clean up the data **on one file first**. By observing the tweets, you can see that:
# 1. Some tweets have URLs in them somehow. We should get rid of them
# 2. We should replace '&amp;' with '&'
# 3. Let's collapse multi-line tweets into single lines.
# 4. The retweets are causing us to have a lot of duplicate tweets... (sad thing of being too poor to afford the paid API, where we can use the `-is:retweet` flag in our search operators)
# 5. Removing commas because I'm not training for grammar and I want to process these tweets in a csv (this is specific for my use case to make my work easier)

# %%
import re, random

def clean_tweet(x):
    if "retweeted_status" in x:
        if "extended_tweet" in x["retweeted_status"]:
            # RETWEET - LONG
            tweet = x["retweeted_status"]["extended_tweet"]["full_text"]
        else:
            # RETWEET - SHORT
            tweet = x["retweeted_status"]["text"]
    elif "extended_tweet" in x:
        # NORMAL TWEET - LONG
        tweet = x["extended_tweet"]["full_text"]
    else:
        # NORMAL TWEET - SHORT
        tweet = x["text"]
        
    # clean up tweet here
    
    # removing all URLs
    tweet = re.sub(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''',
                   '', tweet, flags=re.MULTILINE)
    
    # replacing all URI encoded ampersands with proper ampersands
    tweet = tweet.replace("&amp;", "&")
    
    # removing newlines
    tweet = tweet.replace("\n", "").replace("\r", "")
    
    # removing commas
    tweet = tweet.replace(",", "")
    
    """
    names = ["TOM", "DICK", "HARRY"]
    tweet = re.sub("^@\w+", random.choice(names), tweet)
    pattern = re.compile(" {1}@\w+")
    while pattern.search(tweet):
        tweet = re.sub(" {1}@\w+", " {}".format(random.choice(names)), tweet, count=1)
    """
    
    return tweet

for x in result["results"]:
    print(clean_tweet(x), "\n")
# Out:
# Nerves broken almost a heart attack but overjoyed ❤️ #FCBFCH #DFBPokal
#
# @ecstatic_shocks koreabooism at it’s finest🤡
#
# Special to hit helicopter shot with @msdhoni watching: Hardik"Hoped MS would congratulate me after that shot 😜"An overjoyed @hardikpandya7 talks about emulating inspiration MSD's pet stroke against CSK. Interview by @Moulinparikh #MIvCSK @mipaltan 📹
#
# Thrilled to hear @UnitedWaySummit is expanding their diversity equity & inclusion work! @SummitArtsNow partnered w/ UWSC in March on a social service+arts culture and environment collaboration. Looking forward to the next phase! Thank you Andre Campbell and Adrienne Bradley!
#
# Thrilled to join @PKMackie & @cardiffbusiness for breakfast briefing on homelessness. Thank you for such a warm &  positive response - @LlamauUK &  EYHC’s message is that each and everyone of us in Wales needs to commit to playing our part in preventing and ending homelessness 💪
#
# WATCH: PBB Otso Batch 2 Housemates are all elated meeting each other again. #StarHuntGrandMediacon
#
# Penggunaan "less very" pada kalimatvery sad = sorrowfull very crowded = bustlingvery confused = perplexedvery happy = ecstaticvery difficult = arduousvery quick = rapidvery bad = awfulvery smart = intelligentvery beautiful = kamu
#
# beyond thrilled to announce that i am going to bed!!!
#
# Nervously waiting to find out whether I've got a place at @ActUpNorth after my audition on Monday evening. Lots of experienced actors at the session so not fancying my chances but would be overjoyed if I got in!
#
# I am thrilled to announce that I am the recipient of the 2019 Thrilled to Announce Award.  See you all at the Conference Awards Dinner where I will be thrilled to receive it. Thrilled! 🙏🏻
#
# 【SM fetish BAR gaLa ecstatic】本日4月4日もgaLa ecstaticは20時より、RituaLは22時より営業致します🍾皆様のご来店を心よりお待ちしております💁‍♀️#gaLa #RituaL #神戸BAR #SMbar #カラオケBAR
#
# I was elated seeing these beautiful young girls doing this nation proud last yr defeating U.S China and other countries in the final winning the Gold Medal Award. I doubt if they were honoured and given warm reception by the president till today for this great exploit.
#
# God is not thrilled about self-pity either. Numbers 11:10 KJV[10] Then MOSES HEARD THE PEOPLE WEEP THROUGHOUT THEIR FAMILIES every man in the door of his tent: and THE ANGER OF THE LORD WAS KINDLED GREATLY; Moses also was displeased.
# Thank you! I’m overjoyed by the support & energy we have received!  $231000 in 7 weeks- an average of $75 per donor.   Folks are ready to #SendLindseyHome We will make a BIG announcement soon but we need your help to keep the momentum going!  #JoinJaime
#
# Ecstatic to announce that we've won GOLD in the Indigo Awards 2019 for our CGI work on the Triumph Street Twin Configurator! Details to follow...🥇🥇🥇
#
# @jenichappelle YES!! 💜💜I'm so thrilled you understood it!!
#
# In light of this CAPASSO is ecstatic to announce that during the March 2019 Distribution CAPASSO distributed over R40 million in royalties to members.
#
# Aries (overall): Loki doesn't look too thrilled. Did you forget the mischief again?
#
# Thrilled to announce our paper investigating neural network connectivity changes in people with #aphasia following use of our #iReadMore reading therapy app has been accepted by @SfNJournals #Jneurosci 🎉 S Kerry W Penny @ZWoodhead @oscaraguilarmej @alexander_leff @CrinionJenny
#
# To H'wood celebs whining about @BrianKempGA who are parents: when U first heard UR child’s heartbeat through ultrasound did U yawn “It’s a meaningless sound from a lump of tissue & OK to shred” or did U feel thrilled and say “It’s our baby’s heartbeat!”?
#
# beyond thrilled to announce that i am going to bed!!!
#
# Overjoyed to see such a presence on the program for ACEM ASM 2019 of climate change (and a keynote!) The biggest challenge facing humanity deserves this much attention. Either we go on or we don’t... @healthy_climate @DocsEnvAus @acemonline
#
# Back when Gray was studying in the Phils I was so ecstatic for Recog Day to come coz I was sure she will have an award. But now that we're in AU (which does not have those ribbons and medals unless you are an athlete) I feel sympathetic for those kids without awards.
#
# 🎉🎉 COCO the 🐕 PUG has been FOUND! “Overjoyed to say that Coco has been handed into Bovingdon Vets after being found dumped in Whippendell Woods.” Thank you all for sharing. #reunited #pug #WD33 #croxleygreen #rickmansworth #herts 🎉💕🐶🐾
#
# Thrilled to announce our paper investigating neural network connectivity changes in people with #aphasia following use of our #iReadMore reading therapy app has been accepted by @SfNJournals #Jneurosci 🎉 S Kerry W Penny @ZWoodhead @oscaraguilarmej @alexander_leff @CrinionJenny
#
# @piersmorgan @EmporersNewC Having voted leave I’m ecstatic to have 3 hardline remainers commentating on my reasons for voting leave. 🤦🏻‍♂️ It will never matter how intelligent they are their political stance will always stand in the way of their ability to give arguments capable of persuading leavers
#
# To H'wood celebs whining about @BrianKempGA who are parents: when U first heard UR child’s heartbeat through ultrasound did U yawn “It’s a meaningless sound from a lump of tissue & OK to shred” or did U feel thrilled and say “It’s our baby’s heartbeat!”?
#
# He's done and his cum is leaking out of your wife. She's overjoyed at the orgasm she just had but even more than that she's gleeful because her cuckold is about to eat a creampie out of her.#cuckold #hotwife #cuckoldcaptions #creampiecleanup #cumcleanup #cuckoldcleanup
#
# Thank you! I’m overjoyed by the support & energy we have received!  $231000 in 7 weeks- an average of $75 per donor.   Folks are ready to #SendLindseyHome We will make a BIG announcement soon but we need your help to keep the momentum going!  #JoinJaime
#
# Special to hit helicopter shot with @msdhoni watching: Hardik"Hoped MS would congratulate me after that shot 😜"An overjoyed @hardikpandya7 talks about emulating inspiration MSD's pet stroke against CSK. Interview by @Moulinparikh #MIvCSK @mipaltan 📹
#
# Special to hit helicopter shot with @msdhoni watching: Hardik"Hoped MS would congratulate me after that shot 😜"An overjoyed @hardikpandya7 talks about emulating inspiration MSD's pet stroke against CSK. Interview by @Moulinparikh #MIvCSK @mipaltan 📹
#
# @stevephipps83 @tim_spiers_Star He looks thrilled
#
# The always in-vogue and recognized design fair - #MilanDesign Week starts next week. And we're elated to announce our presence at their  5VIE ART + DESIGN location from 9th - 14th April 2019.#LivingWithElan looks forward to seeing you there!#MilanDesignWeek #Milan #ElanStyle
#
# Thank you! I’m overjoyed by the support & energy we have received!  $231000 in 7 weeks- an average of $75 per donor.   Folks are ready to #SendLindseyHome We will make a BIG announcement soon but we need your help to keep the momentum going!  #JoinJaime
#
# Thank you Trina your trust means a lot for us. We were elated to see you happy and healthy. Enjoy the goodie bag with some extra love for you. #happyclient #bestreview #attorneyreview #goodiebag #clientselfie
#
# @lzjwilliams @CarolAnnCAC @TomKeene647 @stuartbman @ukpenguin We'd be thrilled to see the pins being used in NZ!  If you DM me your address we'll send some over ✈️
#
# @lzjwilliams @CarolAnnCAC @TomKeene647 @stuartbman @ukpenguin We'd be thrilled to see the pins being used in NZ!  If you DM me your address we'll send some over ✈️
#
# We're thrilled to be featured on the Irish Tech News . In an exiting interview with our CEO Eddie Postma about his journey as an entrepreneur and the work we do here at Parksen. @SimonCocking #iot #blockchain #PARQtoken #GoGreen #SmartCity #SmartParking

# %% [markdown]
# Cleaning up the tweets for one file is successful! Time to mass process the rest of the files!

# %%
from glob import glob

dataset = glob(DATASET_ROOT_DIR + "/*")
len(dataset)
# Out:
# 480

# %%
from IPython.display import display, clear_output

tweets, labels, duplicates = [[], [], 0]

for f in dataset:
    with open(f, "r") as file:
        result = json.loads(file.read())
        filename = os.path.basename(file.name)

    classname = filename.split("-")[0]
    for x in result["results"]:
        tweet = clean_tweet(x)
        if tweet not in tweets:
            # unique tweet, add to collections
            tweets.append(tweet)
            labels.append(classname)
        else:
            duplicates += 1

print("{} unique tweets found".format(len(tweets)))
print("{} duplicate tweets".format(duplicates))
# Out:
# 25758 unique tweets found
# 22239 duplicate tweets

# %%
import pandas as pd

df = pd.DataFrame({
    "class" : labels,
    "tweet" : tweets
})
df.head()
# Out:
#       class                                              tweet
# 0  suicidal  "He was lost & scared" says a Newport woman ab...
# 1  suicidal  @TheDumbMedico Ameen. Or ye suicide wali bat a...
# 2  suicidal  You showed the leak in @HouseofCommons today @...
# 3  suicidal  The number in my bio is for a Suicide hotline ...
# 4  suicidal  cw: suicidal ideation it's unsurprisingly hard...

# %%
df.describe()
# Out:
#            class                                              tweet
# count      25758                                              25758
# unique         6                                              25758
# top     cheerful  Why is this limited to girls? Young everyones....
# freq        5885                                                  1

# %%
for key in queries.keys():
    print("{}: {} unique tweets".format(key, df[df["class"] == key].count()[0]))
# Out:
# suicidal: 3204 unique tweets
# depressed: 2561 unique tweets
# sad: 5464 unique tweets
# happy: 5266 unique tweets
# cheerful: 5885 unique tweets
# overjoyed: 3378 unique tweets

# %%
df.to_csv("./datasets/mood_tweets.csv")
